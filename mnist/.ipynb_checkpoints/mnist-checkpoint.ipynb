# %% [markdown]
# # Digit Recognition - MNIST Dataset

# %% [markdown]
# ## Load Dataset

# %%
from keras.datasets import mnist
(x_train, y_train), (x_test, y_test)=mnist.load_data()

# %% [markdown]
# ## Train and Test Sets

# %%
print('Training Samples :: ',x_train.shape[0]/1000,'k',sep='')
print('Training Samples Shape:: ',x_train.shape)

print('Testing Samples :: ',x_test.shape[0]/1000,'k',sep='')
print('Testing Samples Shape:: ',x_test.shape)
# Out:
# Training Samples :: 60.0k
# Training Samples Shape::  (60000, 28, 28)
# Testing Samples :: 10.0k
# Testing Samples Shape::  (10000, 28, 28)

# %% [markdown]
# ## Visualize Few Training Images

# %%
digit=x_train[10]
import matplotlib.pyplot as plt
# %matplotlib inline
fig=plt.figure(figsize=(25,25))
for i in range(6):
    ax=fig.add_subplot(1,6,i+1,xticks=[],yticks=[])
    ax.imshow(x_train[i],cmap=plt.cm.gray)
    ax.set_title(y_train[i])

# %% [markdown]
# ## View an Image in More Detail

# %%
def visualize_input(img, ax):
    ax.imshow(img, cmap='gray')
    width, height = img.shape
    thresh = img.max()/2.5
    for x in range(width):
        for y in range(height):
            ax.annotate(str(round(img[x][y],2)), xy=(y,x),
                        horizontalalignment='center',
                        verticalalignment='center',
                        color='white' if img[x][y]<thresh else 'black')

fig = plt.figure(figsize = (12,12)) 
ax = fig.add_subplot(111)
visualize_input(x_train[4], ax)

# %% [markdown]
# ## Data Preprocessing
#
# > * Previously, our training images, for instance, were stored in an array of shape (60000, 28, 28) of type uint8 with values in the [0, 255] interval.
# > * We transform it into a float32 array of shape (60000, 28 * 28) with values between 0 and 1.

# %%
x_train=x_train.reshape((60000,28*28))
x_train=x_train.astype('float32')/255

x_test=x_test.reshape((10000,28*28))
x_test=x_test.astype('float32')/255

print('Training Samples Shape:: ',x_train.shape)
print('Testing Samples Shape:: ',x_test.shape)
# Out:
# Training Samples Shape::  (60000, 784)
# Testing Samples Shape::  (10000, 784)

# %% [markdown]
# ## Lable Encoding

# %%
from keras.utils import to_categorical

y_train=to_categorical(y_train)
y_test=to_categorical(y_test)

# %% [markdown]
# ## Network Architecture

# %%
from keras import layers
from keras import models

network=models.Sequential()
network.add(layers.Dense(512,activation='relu',input_shape=(28*28,)))
network.add(layers.Dense(10,activation='softmax'))

# %% [markdown]
# ## Compile the Model

# %%
network.compile(optimizer='rmsprop',
               loss='binary_crossentropy',
               metrics=['accuracy'])

# %% [markdown]
# ## Train the Model

# %%
network.fit(x_train,y_train,epochs=5,batch_size=128)
# Out:
# Epoch 1/5
# 60000/60000 [==============================] - 6s - loss: 0.2210 - acc: 0.9179     0
# Epoch 2/5
# 60000/60000 [==============================] - 6s - loss: 0.0958 - acc: 0.9670
# Epoch 3/5
# 60000/60000 [==============================] - 6s - loss: 0.0677 - acc: 0.9784
# Epoch 4/5
# 60000/60000 [==============================] - 6s - loss: 0.0585 - acc: 0.9810
# Epoch 5/5
# 60000/60000 [==============================] - 6s - loss: 0.0539 - acc: 0.9824

# %% [markdown]
# ## Evaluate Model

# %%
test_loss, test_acc=network.evaluate(x_test,y_test)
print('\nTest Loss :: ',test_loss)
print('Test Accuracy :: ',test_acc)
# Out:
#  9632/10000 [===========================>..] - ETA: 0s
# Test Loss ::  0.05058396586701274
# Test Accuracy ::  0.9832100096702576
